# %% [markdown]
# # Analytics

# %% [markdown]
# #### Date: 2021/02
#
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.

# %% [markdown]
# ### TEAM:
#
# ##### Semester: 2021/02
#
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# - Lucas Lopes Xavier
# - João Victor Lustosa Braz
# - Caio César de Almeida Beleza
# - Arthur José Nascimento de Lima
# - Cícero Barrozo Fernandes Filho
# - Gabriel de Souza Fonseca Ribeiro
# - André Macedo Rodrigues Alves
# - Pedro Victor Lima Torreão
# - Daniel Rocha Oliveira
# - Matheus Raphael Soares de Oliveira

# %% [markdown]
# ### LIBRARIES

# %%
# Deal with data
import pandas as pd
import numpy as np
import json

# Deal with API request
import urllib3
from urllib3 import request

# Deal with visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### GRAPH SETTINGS

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(font_scale=1.5)
sns.set_style('darkgrid',
              {'xtick.bottom' : True,
               'ytick.left': True,
               'grid.linestyle':'--',
               'font.monospace': ['Computer Modern Typewriter'],
               'axes.edgecolor' : 'white'})

# %% [markdown]
# ### DATAFRAME SETTINGS

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ### SonarCloud

# %% [markdown]
# #### KEYS

# %%
front_key = 'fga-eps-mds_2021.2-Oraculo-FrontEnd'

# %%
profile_key = 'fga-eps-mds_2021.2-Oraculo-Profile'

# %%
registros_key = 'fga-eps-mds_2021.2-Oraculo-Registros'

# %% [markdown]
# #### METRICS

# %%
metric_list = ['files',
               'functions',
               'complexity',
               'comment_lines_density',
               'duplicated_lines_density',
               'security_rating',
               'tests',
               'test_success_density',
               'test_execution_time',
               'reliability_rating']

len(metric_list)
# Out:
# 10

# %%
def generate_metric_string(metric_list):
    metric_str = ''
    
    for metric in metric_list:
        metric_str += metric + ','
        
    return metric_str

# %%
metric_str = generate_metric_string(metric_list)

# %% [markdown]
# #### URLS

# %%
front_url = f"https://sonarcloud.io/api/measures/component_tree?component={front_key}&metricKeys={metric_str}&ps=500"
profile_url = f"https://sonarcloud.io/api/measures/component_tree?component={profile_key}&metricKeys={metric_str}&ps=500"
registros_url = f"https://sonarcloud.io/api/measures/component_tree?component={registros_key}&metricKeys={metric_str}&ps=500"

# %% [markdown]
# #### API REQUEST

# %%
http = urllib3.PoolManager()

# %%
front_request = http.request('GET', front_url)
front_request.status
# Out:
# 200

# %%
profile_request = http.request('GET', profile_url)
profile_request.status
# Out:
# 200

# %%
registros_request = http.request('GET', registros_url)
registros_request.status
# Out:
# 200

# %%
tags_request = http.request('GET', tags_url)
tags_request.status
# Out:
# 200

# %% [markdown]
# #### JSON DECODING

# %%
front_json = json.loads(front_request.data.decode('utf-8'))
profile_json = json.loads(profile_request.data.decode('utf-8'))
registros_json = json.loads(registros_request.data.decode('utf-8'))

# %% [markdown]
# ## DATA

# %% [markdown]
# ### PROJECT

# %%
project_front_json = front_json['baseComponent']['measures']
project_profile_json = profile_json['baseComponent']['measures']
project_registros_json = registros_json['baseComponent']['measures']

# %%
project_front_data = pd.DataFrame(project_front_json)
project_profile_data = pd.DataFrame(project_profile_json)
project_registros_data = pd.DataFrame(project_registros_json)

# %% [markdown]
# ##### FRONT

# %%
project_front_data
# Out:
#                      metric value bestValue
# 0  duplicated_lines_density   2.9     False
# 1                 functions   384       NaN
# 2           security_rating   1.0      True
# 3                     files   111       NaN
# 4                complexity   538       NaN
# 5        reliability_rating   1.0      True
# 6     comment_lines_density   1.6     False

# %% [markdown]
# ##### BACK

# %%
project_profile_data
# Out:
#                      metric value bestValue
# 0  duplicated_lines_density   0.0      True
# 1                 functions    30       NaN
# 2           security_rating   1.0      True
# 3                     files    11       NaN
# 4                complexity    61       NaN
# 5        reliability_rating   1.0      True
# 6     comment_lines_density   0.6     False

# %%
project_registros_data
# Out:
#                      metric value bestValue
# 0  duplicated_lines_density   0.0      True
# 1                 functions    54       NaN
# 2           security_rating   1.0      True
# 3                     files    18       NaN
# 4                complexity   122       NaN
# 5        reliability_rating   1.0      True
# 6     comment_lines_density   2.7     False

# %% [markdown]
# ### FILES

# %%
def metric_per_file(json):
    file_json = []
    
    for component in json['components']:
        if component['qualifier'] == 'FIL':
            file_json.append(component)
            
    return file_json

# %%
front_file_json = metric_per_file(front_json)
profile_file_json = metric_per_file(profile_json)
registros_file_json = metric_per_file(registros_json)

# %%
def generate_file_dataframe(metric_list, json, language_extension):
    df_columns = metric_list
    df = pd.DataFrame(columns = df_columns)
    
    for file in json:
        try:
            if file['language'] == language_extension:
                for measure in file['measures']:
                    df.at[file['path'], measure['metric']] = measure['value']
        except:
            pass
        
    df.reset_index(inplace = True)
    df = df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)

    return df

# %%
front_files_data = generate_file_dataframe(metric_list, front_file_json, language_extension = 'js')
profile_files_data = generate_file_dataframe(metric_list, profile_file_json, language_extension = 'js')
registros_files_data = generate_file_dataframe(metric_list, registros_file_json, language_extension = 'js')

# %% [markdown]
# ##### FRONT

# %%
front_files_data
# Out:
#                                                 path functions complexity  \
# 0                                         src/App.js         1          1
# 1                                    src/App.test.js         3          3
# 2                                   src/Auth/Auth.js         5          7
# 3      src/Services/Axios/BaseService/baseService.js         6          7
# 4                          src/Constants/baseUrls.js         0          1
# 5    src/Components/DropDownButton/DivSelectSetor.js         0          0
# 6                   src/Constants/federativeUnits.js         0          0
# 7                                     src/history.js         0          0
# 8                                       src/index.js         0          0
# 9                      src/Pages/EditRecord/index.js        27         43
# 10           src/Pages/AllDepartmentsScreen/index.js         9         10
# 11                  src/Pages/ViewAllFields/index.js         4          4
# 12             src/Pages/AllRegistersScreen/index.js         7          8
# 13                     src/Pages/ViewRecord/index.js        24         49
# 14             src/Pages/RegistrationScreen/index.js         8          8
# 15                       src/Pages/HomePage/index.js         6          8
# 16               src/Pages/CreateDepartment/index.js         5          5
# 17                 src/Pages/ChangePassword/index.js         9         14
# 18                   src/Pages/ViewAllUsers/index.js         5          6
# 19                    src/Pages/ViewAllTags/index.js         6          9
# 20                    src/Pages/ViewProfile/index.js         9         11
# 21                     src/Pages/CreateUser/index.js        12         12
# 22                 src/Pages/EditDepartment/index.js         7          9
# 23                    src/Pages/LoginScreen/index.js        10         13
# 24                   src/Pages/CreateRecord/index.js        31         38
# 25                   src/Pages/ViewHistoric/index.js         8         11
# 26               src/Components/Departments/index.js         3          5
# 27                    src/Components/Header/index.js         1          1
# 28               src/Components/FieldsGroup/index.js         1          1
# 29                src/Components/Pagination/index.js         3          4
# 30                   src/Components/Filters/index.js        16         21
# 31              src/Components/PocketFields/index.js         1          1
# 32         src/Components/HeaderWithButtons/index.js        14         17
# 33                  src/Components/Sections/index.js         3          5
# 34                src/Components/MainButton/index.js         1          1
# 35             src/Components/ForwardSector/index.js         2          2
# 36                 src/Components/SearchBar/index.js         2          2
# 37             src/Components/PocketSection/index.js         1          1
# 38         src/Components/GenericBlueButton/index.js         1          1
# 39         src/Components/BigWhiteRectangle/index.js         1          1
# 40            src/Components/DropDownButton/index.js         2          3
# 41        src/Components/GenericWhiteButton/index.js         1          1
# 42          src/Components/PocketDepartment/index.js         2          2
# 43                src/Components/PocketTags/index.js         3          6
# 44              src/Components/FilterButton/index.js         1          1
# 45              src/Components/AddTagDialog/index.js        20         28
# 46          src/Components/ModalDoubleCheck/index.js         2          4
# 47            src/Components/PocketDocument/index.js         5         10
# 48          src/Components/GenericRedButton/index.js         1          1
# 49           src/Components/SectionMovBlock/index.js         1          6
# 50                src/Components/PocketUser/index.js         3          6
# 51          src/Components/BigBlueRectangle/index.js         1          1
# 52                    src/Components/Fields/index.js         3          6
# 53                   src/Components/Process/index.js         4         13
# 54                src/Components/LoginInput/index.js         1          1
# 55            src/Components/CreateTagModal/index.js         8          9
# 56           src/Services/Axios/BaseService/index.js         0          0
# 57              src/Services/Axios/processService.js        23         29
# 58              src/Services/Axios/profileService.js        18         28
# 59                            src/reportWebVitals.js         2          4
# 60                                     src/Routes.js        20         21
# 61                  src/Pages/CreateUser/sections.js         5          8
# 62                                 src/setupTests.js         0          0
# 63                                      src/style.js         0          0
# 64                     src/Pages/ViewRecord/style.js         0          0
# 65               src/Components/Departments/style.js         0          0
# 66                src/Components/Pagination/style.js         0          0
# 67                  src/Components/Sections/style.js         0          0
# 68                src/Components/MainButton/style.js         0          0
# 69                src/Components/PocketUser/style.js         0          0
# 70                    src/Components/Fields/style.js         0          0
# 71                   src/Components/Process/style.js         0          0
# 72                src/Components/LoginInput/style.js         0          0
# 73          src/Pages/AllDepartmentsScreen/styles.js         0          0
# 74                 src/Pages/ViewAllFields/styles.js         0          0
# 75            src/Pages/AllRegistersScreen/styles.js         0          0
# 76            src/Pages/RegistrationScreen/styles.js         0          0
# 77                      src/Pages/HomePage/styles.js         0          0
# 78              src/Pages/CreateDepartment/styles.js         0          0
# 79                src/Pages/ChangePassword/styles.js         0          0
# 80                  src/Pages/ViewAllUsers/styles.js         0          0
# 81                   src/Pages/ViewAllTags/styles.js         0          0
# 82                   src/Pages/ViewProfile/styles.js         0          0
# 83                    src/Pages/CreateUser/styles.js         0          0
# 84                   src/Pages/LoginScreen/styles.js         0          0
# 85                  src/Pages/CreateRecord/styles.js         0          0
# 86                  src/Pages/ViewHistoric/styles.js         0          0
# 87                   src/Components/Header/styles.js         0          0
# 88              src/Components/FieldsGroup/styles.js         0          0
# 89                  src/Components/Filters/styles.js         0          0
# 90             src/Components/PocketFields/styles.js         0          0
# 91        src/Components/HeaderWithButtons/styles.js         0          0
# 92                src/Components/SearchBar/styles.js         0          0
# 93            src/Components/PocketSection/styles.js         0          0
# 94        src/Components/GenericBlueButton/styles.js         0          0
# 95        src/Components/BigWhiteRectangle/styles.js         0          0
# 96       src/Components/GenericWhiteButton/styles.js         0          0
# 97         src/Components/PocketDepartment/styles.js         0          0
# 98               src/Components/PocketTags/styles.js         0          0
# 99             src/Components/FilterButton/styles.js         0          0
# 100            src/Components/AddTagDialog/styles.js         0          0
# 101        src/Components/ModalDoubleCheck/styles.js         0          0
# 102          src/Components/PocketDocument/styles.js         0          0
# 103        src/Components/GenericRedButton/styles.js         0          0
# 104         src/Components/SectionMovBlock/styles.js         0          0
# 105        src/Components/BigBlueRectangle/styles.js         0          0
# 106          src/Components/CreateTagModal/styles.js         0          0
# 107                     src/Pages/ViewRecord/tags.js         5          9
# 108                src/Services/Axios/tagsService.js         1          1
#
#     comment_lines_density duplicated_lines_density security_rating tests  \
# 0                     0.0                      0.0             1.0   NaN
# 1                     0.0                      0.0             1.0   NaN
# 2                    19.2                      0.0             1.0   NaN
# 3                     0.0                      0.0             1.0   NaN
# 4                    28.6                      0.0             1.0   NaN
# 5                     0.0                      0.0             1.0   NaN
# 6                     0.0                      0.0             1.0   NaN
# 7                     0.0                      0.0             1.0   NaN
# 8                    20.0                      0.0             1.0   NaN
# 9                     0.9                      5.8             1.0   NaN
# 10                    5.8                      0.0             1.0   NaN
# 11                    4.2                      0.0             1.0   NaN
# 12                    5.2                      0.0             1.0   NaN
# 13                    1.9                      0.0             1.0   NaN
# 14                    0.0                      0.0             1.0   NaN
# 15                    7.5                      0.0             1.0   NaN
# 16                    1.5                      0.0             1.0   NaN
# 17                    0.0                      0.0             1.0   NaN
# 18                    3.8                      0.0             1.0   NaN
# 19                    5.6                      0.0             1.0   NaN
# 20                    0.9                      0.0             1.0   NaN
# 21                    2.2                      0.0             1.0   NaN
# 22                    1.2                      0.0             1.0   NaN
# 23                    2.8                      0.0             1.0   NaN
# 24                    2.1                      5.4             1.0   NaN
# 25                    2.8                      0.0             1.0   NaN
# 26                    0.0                      0.0             1.0   NaN
# 27                    0.0                      0.0             1.0   NaN
# 28                    0.0                      0.0             1.0   NaN
# 29                    0.0                      0.0             1.0   NaN
# 30                    1.2                      0.0             1.0   NaN
# 31                    0.0                      0.0             1.0   NaN
# 32                    5.3                      0.0             1.0   NaN
# 33                    8.0                      0.0             1.0   NaN
# 34                    0.0                      0.0             1.0   NaN
# 35                    0.0                      0.0             1.0   NaN
# 36                    0.0                      0.0             1.0   NaN
# 37                   11.1                      0.0             1.0   NaN
# 38                    0.0                      0.0             1.0   NaN
# 39                    0.0                      0.0             1.0   NaN
# 40                    0.0                      0.0             1.0   NaN
# 41                    0.0                      0.0             1.0   NaN
# 42                    0.0                      0.0             1.0   NaN
# 43                    0.0                      0.0             1.0   NaN
# 44                    0.0                      0.0             1.0   NaN
# 45                    6.8                      0.0             1.0   NaN
# 46                    0.0                      0.0             1.0   NaN
# 47                    0.0                      0.0             1.0   NaN
# 48                    0.0                      0.0             1.0   NaN
# 49                    0.0                      0.0             1.0   NaN
# 50                    0.0                      0.0             1.0   NaN
# 51                    0.0                      0.0             1.0   NaN
# 52                    6.3                      0.0             1.0   NaN
# 53                    4.5                      0.0             1.0   NaN
# 54                    0.0                      0.0             1.0   NaN
# 55                    2.1                      0.0             1.0   NaN
# 56                    0.0                      0.0             1.0   NaN
# 57                    0.8                      0.0             1.0   NaN
# 58                    2.3                      0.0             1.0   NaN
# 59                    0.0                      0.0             1.0   NaN
# 60                    2.6                      0.0             1.0   NaN
# 61                    0.0                      0.0             1.0   NaN
# 62                    0.0                      0.0             1.0   NaN
# 63                    0.0                      0.0             1.0   NaN
# 64                    0.0                      0.0             1.0   NaN
# 65                    0.0                      0.0             1.0   NaN
# 66                    0.0                      0.0             1.0   NaN
# 67                    0.0                      0.0             1.0   NaN
# 68                    0.0                      0.0             1.0   NaN
# 69                    0.0                      0.0             1.0   NaN
# 70                    0.0                      0.0             1.0   NaN
# 71                    0.0                      0.0             1.0   NaN
# 72                    0.0                      0.0             1.0   NaN
# 73                    0.0                      0.0             1.0   NaN
# 74                    0.0                     95.9             1.0   NaN
# 75                    0.0                      0.0             1.0   NaN
# 76                    0.0                      0.0             1.0   NaN
# 77                    0.0                      0.0             1.0   NaN
# 78                    0.0                      0.0             1.0   NaN
# 79                    0.0                      0.0             1.0   NaN
# 80                    NaN                      0.0             1.0   NaN
# 81                    0.0                     95.9             1.0   NaN
# 82                    0.0                      0.0             1.0   NaN
# 83                    0.0                      0.0             1.0   NaN
# 84                    0.0                      0.0             1.0   NaN
# 85                    0.0                      0.0             1.0   NaN
# 86                    NaN                      0.0             1.0   NaN
# 87                    0.0                      0.0             1.0   NaN
# 88                    0.0                      0.0             1.0   NaN
# 89                    0.0                      0.0             1.0   NaN
# 90                    0.0                      0.0             1.0   NaN
# 91                    0.0                      0.0             1.0   NaN
# 92                    0.0                      0.0             1.0   NaN
# 93                    0.0                      0.0             1.0   NaN
# 94                    0.0                      0.0             1.0   NaN
# 95                    0.0                      0.0             1.0   NaN
# 96                    0.0                      0.0             1.0   NaN
# 97                    0.0                      0.0             1.0   NaN
# 98                    0.0                      0.0             1.0   NaN
# 99                    0.0                      0.0             1.0   NaN
# 100                   0.0                      0.0             1.0   NaN
# 101                   0.0                      0.0             1.0   NaN
# 102                   0.0                      0.0             1.0   NaN
# 103                   0.0                      0.0             1.0   NaN
# 104                   0.0                      0.0             1.0   NaN
# 105                   0.0                      0.0             1.0   NaN
# 106                   0.0                      0.0             1.0   NaN
# 107                   0.0                      0.0             1.0   NaN
# 108                   0.0                      0.0             1.0   NaN
#
#     test_success_density test_execution_time reliability_rating
# 0                  100.0                 NaN                1.0
# 1                  100.0                 NaN                1.0
# 2                  100.0                 NaN                1.0
# 3                  100.0                 NaN                1.0
# 4                  100.0                 NaN                1.0
# 5                  100.0                 NaN                1.0
# 6                  100.0                 NaN                1.0
# 7                  100.0                 NaN                1.0
# 8                  100.0                 NaN                1.0
# 9                  100.0                 NaN                1.0
# 10                 100.0                 NaN                1.0
# 11                 100.0                 NaN                1.0
# 12                 100.0                 NaN                1.0
# 13                 100.0                 NaN                1.0
# 14                 100.0                 NaN                1.0
# 15                 100.0                 NaN                1.0
# 16                 100.0                 NaN                1.0
# 17                 100.0                 NaN                1.0
# 18                 100.0                 NaN                1.0
# 19                 100.0                 NaN                1.0
# 20                 100.0                 NaN                1.0
# 21                 100.0                 NaN                1.0
# 22                 100.0                 NaN                1.0
# 23                 100.0                 NaN                1.0
# 24                 100.0                 NaN                1.0
# 25                 100.0                 NaN                1.0
# 26                 100.0                 NaN                1.0
# 27                 100.0                 NaN                1.0
# 28                 100.0                 NaN                1.0
# 29                 100.0                 NaN                1.0
# 30                 100.0                 NaN                1.0
# 31                 100.0                 NaN                1.0
# 32                 100.0                 NaN                1.0
# 33                 100.0                 NaN                1.0
# 34                 100.0                 NaN                1.0
# 35                 100.0                 NaN                1.0
# 36                 100.0                 NaN                1.0
# 37                 100.0                 NaN                1.0
# 38                 100.0                 NaN                1.0
# 39                 100.0                 NaN                1.0
# 40                 100.0                 NaN                1.0
# 41                 100.0                 NaN                1.0
# 42                 100.0                 NaN                1.0
# 43                 100.0                 NaN                1.0
# 44                 100.0                 NaN                1.0
# 45                 100.0                 NaN                1.0
# 46                 100.0                 NaN                1.0
# 47                 100.0                 NaN                1.0
# 48                 100.0                 NaN                1.0
# 49                 100.0                 NaN                1.0
# 50                 100.0                 NaN                1.0
# 51                 100.0                 NaN                1.0
# 52                 100.0                 NaN                1.0
# 53                 100.0                 NaN                1.0
# 54                 100.0                 NaN                1.0
# 55                 100.0                 NaN                1.0
# 56                 100.0                 NaN                1.0
# 57                 100.0                 NaN                1.0
# 58                 100.0                 NaN                1.0
# 59                 100.0                 NaN                1.0
# 60                 100.0                 NaN                1.0
# 61                 100.0                 NaN                1.0
# 62                 100.0                 NaN                1.0
# 63                 100.0                 NaN                1.0
# 64                 100.0                 NaN                1.0
# 65                 100.0                 NaN                1.0
# 66                 100.0                 NaN                1.0
# 67                 100.0                 NaN                1.0
# 68                 100.0                 NaN                1.0
# 69                 100.0                 NaN                1.0
# 70                 100.0                 NaN                1.0
# 71                 100.0                 NaN                1.0
# 72                 100.0                 NaN                1.0
# 73                 100.0                 NaN                1.0
# 74                 100.0                 NaN                1.0
# 75                 100.0                 NaN                1.0
# 76                 100.0                 NaN                1.0
# 77                 100.0                 NaN                1.0
# 78                 100.0                 NaN                1.0
# 79                 100.0                 NaN                1.0
# 80                 100.0                 NaN                1.0
# 81                 100.0                 NaN                1.0
# 82                 100.0                 NaN                1.0
# 83                 100.0                 NaN                1.0
# 84                 100.0                 NaN                1.0
# 85                 100.0                 NaN                1.0
# 86                 100.0                 NaN                1.0
# 87                 100.0                 NaN                1.0
# 88                 100.0                 NaN                1.0
# 89                 100.0                 NaN                1.0
# 90                 100.0                 NaN                1.0
# 91                 100.0                 NaN                1.0
# 92                 100.0                 NaN                1.0
# 93                 100.0                 NaN                1.0
# 94                 100.0                 NaN                1.0
# 95                 100.0                 NaN                1.0
# 96                 100.0                 NaN                1.0
# 97                 100.0                 NaN                1.0
# 98                 100.0                 NaN                1.0
# 99                 100.0                 NaN                1.0
# 100                100.0                 NaN                1.0
# 101                100.0                 NaN                1.0
# 102                100.0                 NaN                1.0
# 103                100.0                 NaN                1.0
# 104                100.0                 NaN                1.0
# 105                100.0                 NaN                1.0
# 106                100.0                 NaN                1.0
# 107                100.0                 NaN                1.0
# 108                100.0                 NaN                1.0

# %% [markdown]
# ##### BACK

# %%
profile_files_data
# Out:
#                                      path functions complexity  \
# 0                 src/Model/Department.js         3          3
# 1  src/Controller/DepartmentController.js         3          6
# 2                       src/Utils/hash.js         1          1
# 3                            src/index.js         0          1
# 4                   src/Database/index.js         7         12
# 5                        src/Utils/JWT.js         2          4
# 6                      src/Model/Level.js         2          2
# 7                           src/routes.js         0          0
# 8                       src/Model/User.js         2          2
# 9        src/Controller/UserController.js        10         30
#
#   comment_lines_density duplicated_lines_density security_rating tests  \
# 0                   0.0                      0.0             1.0   NaN
# 1                   0.0                      0.0             1.0   NaN
# 2                   0.0                      0.0             1.0   NaN
# 3                   0.0                      0.0             1.0   NaN
# 4                   1.4                      0.0             1.0   NaN
# 5                   0.0                      0.0             1.0   NaN
# 6                   0.0                      0.0             1.0   NaN
# 7                   0.0                      0.0             1.0   NaN
# 8                   0.0                      0.0             1.0   NaN
# 9                   0.9                      0.0             1.0   NaN
#
#   test_success_density test_execution_time reliability_rating
# 0                100.0                 NaN                1.0
# 1                100.0                 NaN                1.0
# 2                100.0                 NaN                1.0
# 3                100.0                 NaN                1.0
# 4                100.0                 NaN                1.0
# 5                100.0                 NaN                1.0
# 6                100.0                 NaN                1.0
# 7                100.0                 NaN                1.0
# 8                100.0                 NaN                1.0
# 9                100.0                 NaN                1.0

# %%
registros_files_data
# Out:
#                                         path functions complexity  \
# 0                    src/Model/Department.js         2          2
# 1     src/Controller/DepartmentController.js         2          3
# 2                    src/Constants/errors.js         0          0
# 3                         src/Model/Field.js         1          1
# 4                       src/Model/History.js         2          2
# 5                               src/index.js         1          3
# 6                      src/Database/index.js         7         13
# 7                        src/Model/Record.js         2          2
# 8         src/Controller/RecordController.js        24         74
# 9                  src/Model/RecordNumber.js         1          1
# 10  src/Controller/RecordNumberController.js         4          9
# 11                             src/routes.js         0          0
# 12                    src/Model/Situation.js         0          0
# 13                          src/Model/Tag.js         2          2
# 14           src/Controller/TagController.js         3          5
# 15                         src/Model/User.js         1          1
# 16          src/Controller/UserController.js         2          4
#
#    comment_lines_density duplicated_lines_density security_rating tests  \
# 0                    0.0                      0.0             1.0   NaN
# 1                    0.0                      0.0             1.0   NaN
# 2                    0.0                      0.0             1.0   NaN
# 3                   40.0                      0.0             1.0   NaN
# 4                    9.4                      0.0             1.0   NaN
# 5                    0.0                      0.0             1.0   NaN
# 6                    6.8                      0.0             1.0   NaN
# 7                    0.0                      0.0             1.0   NaN
# 8                    1.1                      0.0             1.0   NaN
# 9                    0.0                      0.0             1.0   NaN
# 10                   0.0                      0.0             1.0   NaN
# 11                   0.0                      0.0             1.0   NaN
# 12                   0.0                      0.0             1.0   NaN
# 13                   0.0                      0.0             1.0   NaN
# 14                   0.0                      0.0             1.0   NaN
# 15                   0.0                      0.0             1.0   NaN
# 16                   0.0                      0.0             1.0   NaN
#
#    test_success_density test_execution_time reliability_rating
# 0                 100.0                 NaN                1.0
# 1                 100.0                 NaN                1.0
# 2                 100.0                 NaN                1.0
# 3                 100.0                 NaN                1.0
# 4                 100.0                 NaN                1.0
# 5                 100.0                 NaN                1.0
# 6                 100.0                 NaN                1.0
# 7                 100.0                 NaN                1.0
# 8                 100.0                 NaN                1.0
# 9                 100.0                 NaN                1.0
# 10                100.0                 NaN                1.0
# 11                100.0                 NaN                1.0
# 12                100.0                 NaN                1.0
# 13                100.0                 NaN                1.0
# 14                100.0                 NaN                1.0
# 15                100.0                 NaN                1.0
# 16                100.0                 NaN                1.0

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# ## MAINTAINABILITY

# %% [markdown]
# ### CODE QUALITY

# %% [markdown]
# ##### COMPLEXITY

# %%
def m1(df):
    
    density_non_complex_files = round((len(df[(df['complexity'].astype(float)/df['functions'].astype(float)) < 10])/len(df))*100, 2)
    
    return density_non_complex_files

# %% [markdown]
# ##### COMMENTS

# %%
def m2(df):
    
    density_comment_files = round((len(df[(df['comment_lines_density'].astype(float) > 10) & (df['comment_lines_density'].astype(float) < 30)])/len(df))*100, 2)
    
    return density_comment_files

# %% [markdown]
# ##### DUPLICATIONS

# %%
def m3(df):
    
    duplication = round((len(df[(df['duplicated_lines_density'].astype(float) < 5)])/len(df))*100, 2)
    
    return duplication

# %% [markdown]
# ### BLOCKING CODE

# %% [markdown]
# #### NON-BLOCKING FILES

# %%
def m4(df):
    
    non_blocking_files = round((len(df[(df['security_rating'].astype(float) >= 4)])/len(df))*100,2)
    
    return non_blocking_files

# %% [markdown]
# ## RELIABILITY

# %% [markdown]
# #### TEST SUCCESS

# %%
def m5(df):
    
    test_success_file = df[['path', 'test_success_density']]
    test_success_repository = df['test_success_density'].astype(float).mean()
    
    print("Project test unit density: ", test_success_repository)
    
    return test_success_file

# %% [markdown]
# #### FAST TESTS

# %%
def m6(df):
    
    fast_test_df = df[(df['test_execution_time'].astype(float) < 300)]
    fast_test_df['fast_test'] = fast_test_df['test_execution_time']/fast_test_df['tests']
    
    fast_test_file = fast_test_df[['path', 'fast_test']]
    
    fast_test_repository = fast_test_df['fast_test'].astype(float).mean()
    
    print("Project test unit density: ", fast_test_repository)
    
    return fast_test_file

# %% [markdown]
# ## PRODUCTIVITY

# %% [markdown]
# #### RESOLVED ISSUES' THROUGHPUT

# %%
def m7(number_of_issues_resolved, number_of_issues):
    
    resolved_issues_throughput = round((number_of_issues_resolved / number_of_issues) * 100, 2)
    
    return resolved_issues_throughput

# %% [markdown]
# #### ISSUE TYPE IN A TIMEFRAME

# %%
def density(issue, number_of_issues):
    issue_density = round((issue / number_of_issues) * 100, 2)
    return issue_density

# %%
def m8(tag_dict, number_of_issues):
    
    issue_densities = {
        "hotfix": [density(tag_dict["HOTFIX"], number_of_issues)],
        "docs": [density(tag_dict["DOCS"], number_of_issues)],
        "feature": [density(tag_dict["FEATURE"], number_of_issues)],
        "arq": [density(tag_dict["ARQ"], number_of_issues)],
        "devops": [density(tag_dict["DEVOPS"], number_of_issues)],
        "analytics": [density(tag_dict["ANALYTICS"], number_of_issues)],
        "us": [density(tag_dict["US"], number_of_issues)],
        "easy": [density(tag_dict["EASY"], number_of_issues)],
        "medium": [density(tag_dict["MEDIUM"], number_of_issues)],
        "hard": [density(tag_dict["HARD"], number_of_issues)],
        "eps": [density(tag_dict["EPS"], number_of_issues)],
        "mds": [density(tag_dict["MDS"], number_of_issues)]
    }

    issue_densities = pd.DataFrame.from_dict(issue_densities).T.reset_index()
    issue_densities.columns = ['density' ,'percentage']
    
    return issue_densities

# %% [markdown]
# #### BUGS RATIO

# %%
def m9(tag_dict, number_of_issues): 
    bugs_ratio = round(((tag_dict["DOCS"] + tag_dict["FEATURE"] + tag_dict["ARQ"] + tag_dict["DEVOPS"] + tag_dict["ANALYTICS"]) / number_of_issues) * 100, 2)

    return bugs_ratio

# %% [markdown]
# ### TIMEFRAME: SPRINT 1

# %%
SPRINT = 1
NUMBER_OF_ISSUES_RESOLVED = 0
NUMBER_OF_ISSUES = 22

TAGS = {
    "HOTFIX": 0,
    "DOCS": 13,
    "FEATURE": 0,
    "ARQ": 0,
    "DEVOPS": 2,
    "ANALYTICS": 1,
    "US":  0,
    "EASY":  0,
    "MEDIUM": 0,
    "HARD": 0,
    "EPS": 18,
    "MDS": 4,

}

# %%
sprint1_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
sprint1_m8 = m8(TAGS, NUMBER_OF_ISSUES)
sprint1_m9 = m9(TAGS, NUMBER_OF_ISSUES)

# %% [markdown]
# ### TIMEFRAME: SPRINT 2

# %%
SPRINT = 2
NUMBER_OF_ISSUES_RESOLVED = 24
NUMBER_OF_ISSUES = 24

TAGS = {
    "HOTFIX": 1,
    "DOCS": 13,
    "FEATURE": 0,
    "ARQ": 0, 
    "DEVOPS": 2, 
    "ANALYTICS": 1, 
    "US": 0, 
    "EASY": 0, 
    "MEDIUM": 0, 
    "HARD": 0, 
    "EPS": 19, 
    "MDS": 4, 

}

# %%
sprint2_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
sprint2_m8 = m8(TAGS, NUMBER_OF_ISSUES)
sprint2_m9 = m9(TAGS, NUMBER_OF_ISSUES)

# %% [markdown]
# ### TIMEFRAME: SPRINT 3

# %%
SPRINT = 3
NUMBER_OF_ISSUES_RESOLVED = 3
NUMBER_OF_ISSUES = 3

TAGS = {
     
    "HOTFIX": 0,
    "DOCS": 0,
    "FEATURE": 0, 
    "ARQ": 0,
    "DEVOPS": 0, 
    "ANALYTICS": 0, 
    "US": 0,
    "EASY": 0, 
    "MEDIUM": 0, 
    "HARD": 0,
    "EPS": 0, 
    "MDS": 3, 
}

# %%
sprint3_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
sprint3_m8 = m8(TAGS, NUMBER_OF_ISSUES)
sprint3_m9 = m9(TAGS, NUMBER_OF_ISSUES)

# %% [markdown]
# ### TIMEFRAME: SPRINT 4

# %%
SPRINT = 4
NUMBER_OF_ISSUES_RESOLVED = 4
NUMBER_OF_ISSUES = 4

TAGS = {
   "HOTFIX": 0,
    "DOCS": 1,
    "FEATURE": 1, 
    "ARQ": 0,
    "DEVOPS": 0, 
    "ANALYTICS": 0, 
    "US": 2,
    "EASY": 0, 
    "MEDIUM": 0,  
    "HARD": 0,
    "EPS": 1, 
    "MDS": 3,
}

# %%
sprint4_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
sprint4_m8 = m8(TAGS, NUMBER_OF_ISSUES)
sprint4_m9 = m9(TAGS, NUMBER_OF_ISSUES)

# %% [markdown]
# ### TIMEFRAME: SPRINT 5

# %%
SPRINT = 5
NUMBER_OF_ISSUES_RESOLVED = 0
NUMBER_OF_ISSUES = 7

TAGS = {
    "HOTFIX": 0,
    "DOCS": 1,
    "FEATURE": 1,  
    "ARQ": 0,
    "DEVOPS": 0,  
    "ANALYTICS": 1,  
    "US": 2,
    "EASY": 0,  
    "MEDIUM": 0,  
    "HARD": 0,
    "EPS": 2, 
    "MDS": 4,
}

# %%
sprint5_m7 = m7(NUMBER_OF_ISSUES_RESOLVED, NUMBER_OF_ISSUES)
sprint5_m8 = m8(TAGS, NUMBER_OF_ISSUES)
sprint5_m9 = m9(TAGS, NUMBER_OF_ISSUES)

# %% [markdown]
# ### METRIC RESULTS

# %% [markdown]
# #### M1 Results

# %%
front_m1 = m1(front_files_data)
profile_m1 = m1(profile_files_data)
registros_m1 = m1(registros_files_data)

m1_results = {"Repository": ["Front End", "Profile", "Registros"], "Results": [front_m1, profile_m1, registros_m1]}

m1_results = pd.DataFrame(data=m1_results)

m1_results.style.hide_index

m1_results
# Out:
#   Repository  Results
# 0  Front End    53.21
# 1    Profile    80.00
# 2  Registros    82.35

# %% [markdown]
# #### M2 Results

# %%
front_m2 = m2(front_files_data)
profile_m2 = m2(profile_files_data)
registros_m2 = m2(registros_files_data)


m2_results = {"Repository": ["Front End", "Profile", "Registros"], "Results": [front_m2, profile_m2, registros_m2]}

m2_results = pd.DataFrame(data=m2_results)

m2_results.style.hide_index

m2_results
# Out:
#   Repository  Results
# 0  Front End     3.67
# 1    Profile     0.00
# 2  Registros     0.00

# %% [markdown]
# #### M3 Results

# %%
front_m3 = m3(front_files_data)
profile_m3 = m3(profile_files_data)
registros_m3 = m3(registros_files_data)


m3_results = {"Repository": ["Front End", "Profile", "Registros"], "Results": [front_m3, profile_m3, registros_m3]}

m3_results = pd.DataFrame(data=m3_results)

m3_results.style.hide_index

m3_results
# Out:
#   Repository  Results
# 0  Front End    96.33
# 1    Profile   100.00
# 2  Registros   100.00

# %% [markdown]
# #### M4 Results

# %%
front_m4 = m4(front_files_data)
profile_m4 = m4(profile_files_data)
registros_m4 = m4(registros_files_data)


m4_results = {"Repository": ["Front End", "Profile", "Registros"], "Results": [front_m4, profile_m4, registros_m4]}

m4_results = pd.DataFrame(data=m4_results)

m4_results.style.hide_index

m4_results
# Out:
#   Repository  Results
# 0  Front End      0.0
# 1    Profile      0.0
# 2  Registros      0.0

# %% [markdown]
# #### M5 Results

# %%
front_m5 = m5(front_files_data)
profile_m5 = m5(profile_files_data)
registros_m5 = m5(registros_files_data)


m5_results = {"Repository": ["Front End", "Profile", "Registros"], "Results": [front_m5, profile_m5, registros_m5]}

m5_results = pd.DataFrame(data=m5_results)

m5_results.style.hide_index

m5_results
# Out:
# Project test unit density:  100.0
# Project test unit density:  100.0
# Project test unit density:  100.0
#   Repository                                            Results
# 0  Front End                                                ...
# 1    Profile                                       path test...
# 2  Registros                                          path t...

# %% [markdown]
# #### M6 Results

# %%
front_m6 = m6(front_files_data)
profile_m6 = m6(profile_files_data)
registros_m6 = m6(registros_files_data)


m6_results = {"Repository": ["Front End", "Profile", "Registros"], "Results": [front_m6, profile_m6, registros_m6]}

m6_results = pd.DataFrame(data=m6_results)

m6_results.style.hide_index

m6_results
# Out:
# Project test unit density:  nan
# Project test unit density:  nan
# Project test unit density:  nan
#   Repository                                            Results
# 0  Front End  Empty DataFrame
# Columns: [path, fast_test]
# Ind...
# 1    Profile  Empty DataFrame
# Columns: [path, fast_test]
# Ind...
# 2  Registros  Empty DataFrame
# Columns: [path, fast_test]
# Ind...

# %% [markdown]
# #### M7 Results

# %%
sprint1_m7
sprint2_m7
sprint3_m7
sprint4_m7
sprint5_m7

m7_results = {"Sprint": [1,2,3,4,5], "Results": [sprint1_m7,sprint2_m7,sprint3_m7,sprint4_m7,sprint5_m7]}
m7_results = pd.DataFrame(data=m7_results)
m7_results
# Out:
#    Sprint  Results
# 0       1      0.0
# 1       2    100.0
# 2       3    100.0
# 3       4    100.0
# 4       5      0.0

# %% [markdown]
# #### M8 Results

# %%
sprint1_m8
sprint2_m8
sprint3_m8
sprint4_m8
sprint5_m8

m8_list = [sprint1_m8,sprint2_m8,sprint3_m8,sprint4_m8,sprint5_m8]

for i in range(len(m8_list)):
    print("Sprint {sprint}".format(sprint=i))
    display(m8_list[i])
# Out:
# Sprint 0
#       density  percentage
# 0      hotfix        0.00
# 1        docs       59.09
# 2     feature        0.00
# 3         arq        0.00
# 4      devops        9.09
# 5   analytics        4.55
# 6          us        0.00
# 7        easy        0.00
# 8      medium        0.00
# 9        hard        0.00
# 10        eps       81.82
# 11        mds       18.18
# Sprint 1
#       density  percentage
# 0      hotfix        4.17
# 1        docs       54.17
# 2     feature        0.00
# 3         arq        0.00
# 4      devops        8.33
# 5   analytics        4.17
# 6          us        0.00
# 7        easy        0.00
# 8      medium        0.00
# 9        hard        0.00
# 10        eps       79.17
# 11        mds       16.67
# Sprint 2
#       density  percentage
# 0      hotfix         0.0
# 1        docs         0.0
# 2     feature         0.0
# 3         arq         0.0
# 4      devops         0.0
# 5   analytics         0.0
# 6          us         0.0
# 7        easy         0.0
# 8      medium         0.0
# 9        hard         0.0
# 10        eps         0.0
# 11        mds       100.0
# Sprint 3
#       density  percentage
# 0      hotfix         0.0
# 1        docs        25.0
# 2     feature        25.0
# 3         arq         0.0
# 4      devops         0.0
# 5   analytics         0.0
# 6          us        50.0
# 7        easy         0.0
# 8      medium         0.0
# 9        hard         0.0
# 10        eps        25.0
# 11        mds        75.0
# Sprint 4
#       density  percentage
# 0      hotfix        0.00
# 1        docs       14.29
# 2     feature       14.29
# 3         arq        0.00
# 4      devops        0.00
# 5   analytics       14.29
# 6          us       28.57
# 7        easy        0.00
# 8      medium        0.00
# 9        hard        0.00
# 10        eps       28.57
# 11        mds       57.14

# %% [markdown]
# #### M9 Results

# %%
sprint1_m9
sprint2_m9
sprint3_m9
sprint4_m9
sprint5_m9

m9_results = {"Sprint": [1,2,3,4,5], "Results": [sprint1_m9,sprint2_m9,sprint3_m9,sprint4_m9,sprint5_m9]}
m9_results = pd.DataFrame(data=m9_results)
m9_results
# Out:
#    Sprint  Results
# 0       1    72.73
# 1       2    66.67
# 2       3     0.00
# 3       4    50.00
# 4       5    42.86
